# %% [markdown]
# <a href="https://colab.research.google.com/github/dlcastan/ProyectoDS/blob/main/ProyectoDS_ParteI_Lopez_Castan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Curso:** Data Science I: Fundamentos para la Ciencia de Datos
# # **Comisión 61170**
# # **Alumno:** Diego Lopez Castan

# %% [markdown]
# # Abstract
#
# El Conjunto de Datos que presente tiene registros que describen las compras realizadas por los usuarios de un ecommerce. He seleccionado este dataset porque mi idea es poder distinguir insights sobre Comportamiento del Consumidor y Hábitos de Compra. Quiero encontrar preferencias, tendencias y patrones de los consumidores de sus compra.
#
# Otro tema importate por que seleccioné este conjunto de datos es porque posee una gran de variables, como por ejemplo información demográfica, historial de compras, preferencias de productos, frecuencia de compra y comportamiento de compra en línea/fuera de línea.
#
#
# # Hipotesis
#
# El dataset tiene la posibilidad de describir varias aristas sobre la compra de los clientes.
#
#
# **Preferencias de Producto por Demografía:**
#
# Los consumidores de diferentes grupos demográficos (edad, género, ubicación) tienen preferencias de productos distintas.
#
#
# **Frecuencia de Compra por producto y por estación:**
#
# Los clientes que compran productos diferentes según a estación del año.
#
# **Impacto de las Promociones en el Comportamiento de Compra:**
#
# Las promociones y descuentos tienen un impacto significativo en el comportamiento de compra de los consumidores, aumentando la cantidad y frecuencia de las compras.
#
# **Efecto de las Reseñas y Calificaciones en las Decisiones de Compra:**
#
# Las reseñas y calificaciones de productos influyen significativamente en las decisiones de compra de los consumidores.
#
# **Impacto de los metodos de pago en las compras:**
#
# Las promociones y descuentos tienen un impacto significativo en el comportamiento de compra de los consumidores, aumentando la cantidad y frecuencia de las compras.
#
# Tiene el impacto en la compra el modo de pago empleado por el cliente? Existe alguna diferencia entre tarjeta de crédito,  efectivo u otro medio?

# %% [markdown]
# # Campos del dataset
#
# **Customer ID:** Un identificador único asignado a cada cliente individual, que facilita el seguimiento y análisis de su comportamiento de compra a lo largo del tiempo.
#
# **Age:** La edad del cliente, que proporciona información demográfica para la segmentación y estrategias de marketing dirigidas.
#
# **Gender:** La identificación de género del cliente, una variable demográfica clave que influye en las preferencias de productos y patrones de compra.
#
# **Item Purchased:** El producto o artículo específico seleccionado por el cliente durante la transacción.
#
# **Category:** La clasificación amplia o grupo al que pertenece el artículo comprado (por ejemplo, ropa, electrónica, comestibles).
#
# **Purchase Amount (USD):** El valor monetario de la transacción, indicado en dólares estadounidenses (USD), que indica el costo del(los) artículo(s) comprado(s).
#
# **Location:** La ubicación geográfica donde se realizó la compra, que ofrece información sobre preferencias regionales y tendencias del mercado.
#
# **Size:** La especificación de tamaño (si aplica) del artículo comprado, relevante para ropa, calzado y ciertos bienes de consumo.
#
# **Color:** La variante o elección de color asociada con el artículo comprado, que influye en las preferencias del cliente y la disponibilidad del producto.
#
# **Season:** La relevancia estacional del artículo comprado (por ejemplo, primavera, verano, otoño, invierno), que impacta la gestión de inventarios y estrategias de marketing.
#
# **Review Rating:** Una evaluación numérica o cualitativa proporcionada por el cliente sobre su satisfacción con el artículo comprado.
#
# **Subscription Status:** Indica si el cliente ha optado por un servicio de suscripción, ofreciendo información sobre su nivel de lealtad y potencial para ingresos recurrentes.
#
# **Shipping Type:** Especifica el método utilizado para entregar el artículo comprado (por ejemplo, envío estándar, entrega exprés), que influye en los tiempos y costos de entrega.
#
# **Discount Applied:** Indica si se aplicaron descuentos promocionales a la compra, proporcionando información sobre la sensibilidad al precio y la efectividad de las promociones.
#
# **Promo Code Used:** Nota si se utilizó un código promocional o cupón durante la transacción, ayudando en la evaluación del éxito de las campañas de marketing.
#
# **Previous Purchases:** Proporciona información sobre la cantidad o frecuencia de compras anteriores realizadas por el cliente, contribuyendo a las estrategias de segmentación y retención de clientes.
#
# **Payment Method:** Especifica el modo de pago empleado por el cliente (por ejemplo, tarjeta de crédito, efectivo), ofreciendo información sobre las opciones de pago preferidas.
#
# **Frequency of Purchases:** Indica con qué frecuencia el cliente realiza actividades de compra, una métrica crítica para evaluar la lealtad del cliente y su valor a lo largo del tiempo.

# %% [markdown]
# # Analisis Descriptivo

# %%
# Cargo las librerías
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Leo archivo
data = pd.read_csv('https://raw.githubusercontent.com/dlcastan/ProyectoDS/main/shopping_behavior_updated.csv')
data.replace([np.inf, -np.inf], np.nan, inplace=True)

# %% [markdown]
# ## Analisis Básico

# %%
data.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
#Identifico los las columnas de mi dataframe
data.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %%
#Describo los tipos de datos
data.dtypes
# Out:
# Customer ID                 int64
# Age                         int64
# Gender                     object
# Item Purchased             object
# Category                   object
# Purchase Amount (USD)       int64
# Location                   object
# Size                       object
# Color                      object
# Season                     object
# Review Rating             float64
# Subscription Status        object
# Shipping Type              object
# Discount Applied           object
# Promo Code Used            object
# Previous Purchases          int64
# Payment Method             object
# Frequency of Purchases     object
# dtype: object

# %%
#Controlo si existe valores nullos
data.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %% [markdown]
# # Análisis Exploratorio

# %%
# Gráfico de torta para el género
gender_counts = data['Gender'].value_counts()
colors = ['mediumseagreen', 'steelblue']
plt.figure(figsize=(5, 5))
gender_counts.plot.pie(autopct='%1.1f%%', startangle=90, colors=colors)
plt.title('Distribución por Género')
plt.ylabel('')
plt.show()

# %%
# Gráfico de torta para el género
gender_counts = data['Payment Method'].value_counts()
colors = ['mediumseagreen', 'forestgreen', 'turquoise', 'steelblue', 'royalblue', 'deepskyblue']
plt.figure(figsize=(5, 5))
gender_counts.plot.pie(autopct='%1.1f%%', startangle=90, colors=colors)
plt.title('Distribución por Método de Pagos')
plt.ylabel('')
plt.show()

# %%
# Gráfico de torta para las compras por estación
gender_counts = data['Season'].value_counts()
colors = ['mediumseagreen', 'forestgreen', 'turquoise', 'steelblue', 'royalblue', 'deepskyblue']
plt.figure(figsize=(5, 5))
gender_counts.plot.pie(autopct='%1.1f%%', startangle=90, colors=colors)
plt.title('Distribución por Estación')
plt.ylabel('')
plt.show()

# %%
# Gráfico de compras por codigo de promoción
gender_counts = data['Promo Code Used'].value_counts()
colors = ['mediumseagreen', 'steelblue']
plt.figure(figsize=(5, 5))
gender_counts.plot.pie(autopct='%1.1f%%', startangle=90, colors=colors)
plt.title('Distribución de compras por codigo de promoción')
plt.ylabel('')
plt.show()

# %%
# Grafico la distribución por edad
plt.figure(figsize=(10, 6))
sns.histplot(data['Age'], bins=10, palette='crest', edgecolor='black')
plt.title('Grafico la distribución por edad')
plt.xlabel('Edad')
plt.ylabel('Cantidad')
plt.show()
# Out:
# <ipython-input-15-d87f996f61de>:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data['Age'], bins=10, palette='crest', edgecolor='black')

# %%
# Grafico la distribución por edad por sexo
colors = ['mediumseagreen', 'steelblue']
count_by_age_gender = data.groupby(['Age', 'Gender']).size().unstack()
count_by_age_gender = count_by_age_gender.sort_index()
count_by_age_gender.plot(kind='bar', figsize=(12, 8), color=colors)
# Out:
# <Axes: xlabel='Age'>

# %%
# Grafico de consumidores por localidad
plt.figure(figsize=(12, 6))
sns.countplot(x='Location', data=data, order=data['Location'].value_counts().iloc[:10].index, palette='viridis', hue='Gender')
plt.title('Cantidad de Clientes por Localidad')
plt.xlabel('Localidad')
plt.ylabel('Cantidad de Clientes')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# **Las localidades de los clientes de sexo masculino que más compran son de California y de Nueva York. En cambio las mujeres compran más de Montana y de Idaho.**

# %%
# Contar la cantidad de clientes por categoría de producto
category_counts = data['Category'].value_counts()
plt.figure(figsize=(12, 8))
category_counts.plot(kind='bar', color=sns.color_palette('crest', len(category_counts)))
plt.title('Cantidad de Clientes por Categoría de Producto')
plt.xlabel('Categoría de Producto')
plt.ylabel('Cantidad de Clientes')
plt.show()

# %% [markdown]
# **Las categorías más compradas por los clientes es de indumentaria, seguida por accesorios.**

# %%
# Cantidad de clientes de las 10 categorías de productos principales
plt.figure(figsize=(12, 6))
sns.countplot(x='Category', data=data, order=data['Category'].value_counts().iloc[:10].index, palette='crest', hue='Gender')
plt.title('Cantidad de clientes por categoría de producto')
plt.xlabel('Categoria del Producto')
plt.ylabel('Cantidad de Clientes')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# **Al analizar las categorias por producto se puede ver que los hombres son los que más compran, siendo más evidente las categorías de vestimenta y accesorios.**

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Category', y='Purchase Amount (USD)', hue='Season', data=data, palette='crest')
plt.title('Promedio de compras por categoría de producto y temporada')
plt.xlabel('Categoria de Producto')
plt.ylabel('Importe medio de compra (USD)')
plt.xticks(rotation=45)
plt.legend(title='Estación')
plt.grid(True)
plt.show()

# %% [markdown]
# **En cuanto al análisis de compras por estación, los clientes compran más en otoño.**

# %%
# Cantidad de transacciones por metodo de pago y sexo
plt.figure(figsize=(10, 6))
sns.countplot(x='Payment Method', hue='Gender', data=data, palette='crest', hue_order=['Male', 'Female'])
plt.title('Preferred Payment Methods Among Customers by Gender')
plt.xlabel('Payment Method')
plt.ylabel('Number of Transactions')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.grid(True)
plt.show()

# %% [markdown]
# **Al analizar los métodos de pago se puede identificar que los hombres prefieren principalmente Tarjeta de débito, Tarjeta de crédito y en efectivo. En cambio, las mujeres usan más Paypal o Tarjeta de Crédito.**

# %%
# Cantidad de transacciones por método de pago por categoría
plt.figure(figsize=(10, 6))
sns.countplot(x='Payment Method', hue='Category', data=data, palette='crest')
plt.title('Métodos de pago preferidos por categoría de producto')
plt.xlabel('Metodos de Pago')
plt.ylabel('Cantidad de transacciones')
plt.xticks(rotation=45)
plt.legend(title='Categoria de productos')
plt.grid(True)
plt.show()

# %%
# Defino grupo de clientes
age_groups = {
    'Compradores entre 13 y 25': (13, 19),
    'Compradores entre 26 y 40': (26, 40),
    'Compradores entre 41 y 60': (41, 60),
    'Compradores más de 60': (60, 100)
}

def assign_age_group(age):
    for group, (lower, upper) in age_groups.items():
        if lower <= age <= upper:
            return group
    return 'Unknown'

# Creo nueva columna por grupo de usuario
data['Age Group'] = data['Age'].apply(assign_age_group)

# %%
# Grafico compras por grupo de usuarios
plt.figure(figsize=(10, 6))
sns.countplot(x='Age Group', data=data, palette='crest', hue='Age Group', order=age_groups.keys())
plt.title('Compras por Grupo de edad')
plt.xlabel('Grupo de edad')
plt.ylabel('Frecuencia de Compras')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# **El segmento de edad de clientes que más compran son los cientes de entre 41 y 60 años. Seguidos por los Cliente de entre 24 y 40. Los clientes que menos compran son los clientes de entre 13 y 25 años.**

# %%
# Grafico de categorias por grupo de edad
plt.figure(figsize=(10, 6))
sns.countplot(x='Category', hue='Age Group', data=data, palette='crest', hue_order=age_groups.keys())
plt.title('Categoria de productos por Grupo de Edad')
plt.xlabel('Categoria de Productos')
plt.ylabel('Frequencia')
plt.xticks(rotation=45)
plt.legend(title='Grupo de Edad')
plt.grid(True)
plt.show()

# %% [markdown]
# **Al analizar las compras por grupo podemos identificar que los usuarios de entre 13 y 25 años compran principalmente vestimenta y accesorios. Los usuarios de entre 26 y 40 años compran principalmente indimentaria, dejando muy lejos a la segunda categoria vestimenta. El tercer grupo de clientes de entre 41 y 60 años al igual que el grupo anterior compran principalmente vestimenta y accesorios. Los clientes de más de 60 compran mucho más indumentaria que accesorios.**

# %%
# Compras por promocion y edad
plt.figure(figsize=(10, 6))
sns.countplot(x='Discount Applied', hue='Age Group', data=data, palette='crest', hue_order=age_groups.keys())
plt.title('Compras con promociones por Grupo de edad')
plt.xlabel('Descuento aplicado')
plt.ylabel('Frecuencia')
plt.xticks(rotation=45)
plt.legend(title='Grupos de Edad')
plt.grid(True)
plt.show()

# %% [markdown]
# **Los clientes que más usan promociones son los clientes de entre 41 y 60 años.**

# %% [markdown]
# # Conclusiones

# %% [markdown]
# El análisis de los datos de ventas y comportamiento de compra de los clientes revela varias tendencias significativas en función de la localidad, género, categorías de productos, estación del año, métodos de pago y segmentos de edad.
#
# **Localidades de Clientes:**
#
# Los clientes masculinos que más compran se concentran en California y Nueva York.
# Las mujeres, en cambio, compran más desde Montana e Idaho.
#
# **Categorías de Productos:**
#
# Las categorías más compradas por los clientes en general son indumentaria, seguida por accesorios.
# Dentro del análisis de categorías por producto, los hombres predominan en las compras de vestimenta y accesorios.
#
# **Estación del Año:**
#
# Las compras alcanzan su punto más alto durante el otoño.
#
# **Métodos de Pago:**
#
# Los hombres prefieren principalmente pagar con tarjeta de débito, tarjeta de crédito y en efectivo.
# Las mujeres, por su parte, usan más Paypal o tarjeta de crédito para realizar sus compras.
#
# **Segmentos de Edad:**
#
# El grupo de edad que más compra está compuesto por clientes de entre 41 y 60 años, seguido por aquellos de entre 24 y 40 años.
# Los clientes de entre 13 y 25 años son los que menos compran.
# En términos de categorías de productos, los clientes de entre 13 y 25 años se inclinan por vestimenta y accesorios.
# Los clientes de entre 26 y 40 años compran mayoritariamente indumentaria, con una notable diferencia respecto a otras categorías.
# Los clientes de entre 41 y 60 años, similarmente, prefieren indumentaria y accesorios.
# Los clientes mayores de 60 años compran considerablemente más indumentaria que accesorios.
#
# **Uso de Promociones:**
#
# Los clientes de entre 41 y 60 años son los que más aprovechan las promociones disponibles.
# En resumen, el comportamiento de compra varía significativamente según varios factores demográficos y de preferencias. Estos hallazgos permiten identificar oportunidades para personalizar estrategias de marketing, promociones y oferta de productos, optimizando así la satisfacción del cliente y potenciando las ventas.
